# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import  missingno as msno

import seaborn as sns
from scipy import stats
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.inspection import permutation_importance
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df = pd.read_csv(r'C:\Users\HAMTA\Desktop\AI\titanic (1).csv')
df.head()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.isna().sum(axis=1)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    2
# 889    0
# 890    1
# Length: 891, dtype: int64

# %%
for columns in df.select_dtypes('object'):
    uniq_value = df[columns].unique()
    nuniq_value = df[columns].nunique()
    print(f'مقادیر یونیگ در ستون {columns} : {uniq_value}')
    print(f'{columns} : {nuniq_value}')
# Out:
# مقادیر یونیگ در ستون Name : <StringArray>
# [                            'Braund, Mr. Owen Harris',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#                               'Heikkinen, Miss. Laina',
#         'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#                             'Allen, Mr. William Henry',
#                                     'Moran, Mr. James',
#                              'McCarthy, Mr. Timothy J',
#                       'Palsson, Master. Gosta Leonard',
#    'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#                  'Nasser, Mrs. Nicholas (Adele Achem)',
#  ...
#                                   'Markun, Mr. Johann',
#                         'Dahlberg, Miss. Gerda Ulrika',
#                        'Banfield, Mr. Frederick James',
#                               'Sutehall, Mr. Henry Jr',
#                 'Rice, Mrs. William (Margaret Norton)',
#                                'Montvila, Rev. Juozas',
# ...

# %%
df["Age"].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df[['Name','Sex']] = df[['Name','Sex']].astype('category')
df.dtypes
# Out:
# PassengerId       int64
# Survived          int64
# Pclass            int64
# Name           category
# Sex            category
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket              str
# Fare            float64
# Cabin               str
# Embarked            str
# dtype: object

# %%
def describe(df):

    variables = []
    dtypes = []
    count = []
    unique = []
    missing = []

    for item in df.columns:
        variables.append(item)
        dtypes.append(df[item].dtype)
        count.append(len(df[item]))
        unique.append(len(df[item].unique()))
        missing.append(df[item].isna().sum())

    output = pd.DataFrame({
        'variable':variables,
        'Dtype' : dtypes,
        'Count' : count,
        'Unique':unique,
        'Missing value':missing
    })
    return output

# %%
describe(df)
# Out:
#        variable     Dtype  Count  Unique  Missing value
# 0   PassengerId     int64    891     891              0
# 1      Survived     int64    891       2              0
# 2        Pclass     int64    891       3              0
# 3          Name  category    891     891              0
# 4           Sex  category    891       2              0
# 5           Age   float64    891      89            177
# 6         SibSp     int64    891       7              0
# 7         Parch     int64    891       7              0
# 8        Ticket       str    891     681              0
# 9          Fare   float64    891     248              0
# 10        Cabin       str    891     148            687
# 11     Embarked       str    891       4              2

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum() / df.shape[0] * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
df =df.drop('PassengerId', axis=1)
df =df.drop('Name', axis=1)
df =df.drop('Ticket', axis=1)
df =df.drop('Cabin', axis=1) 

df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df['Embarked'].isna().sum()

df = df.dropna(subset=['Embarked'])

df = df.reset_index(drop=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 884         0       2    male  27.0      0      0  13.0000        S
# 885         1       1  female  19.0      0      0  30.0000        S
# 886         0       3  female   NaN      1      2  23.4500        S
# 887         1       1    male  26.0      0      0  30.0000        C
# 888         0       3    male  32.0      0      0   7.7500        Q
#
# [889 rows x 8 columns]

# %%
def diagnose_mv(df, mv_column):
    cols = list(df.columns)
    cols.remove(mv_column)

    flags = df[mv_column].isna()

    fig, ax = plt.subplots(len(cols), 3,
                           figsize=(15, 4*len(cols)),
                           constrained_layout=True)

    plt.rcParams['axes.grid'] = True

    for i, col in enumerate(cols):

        if pd.api.types.is_numeric_dtype(df[col]):

            n1, bins, _ = ax[i,0].hist(df[col].dropna())
            ax[i,0].set_title(f'{col} with MV')

            n2, _, _ = ax[i,1].hist(df.loc[~flags, col].dropna(), bins=bins)
            ax[i,1].set_title(f'{col} without MV')

            ax[i,2].bar(bins[:-1], np.abs(n2-n1), width=np.abs(bins[1]-bins[0]))
            ax[i,2].set_title('Difference')

        else:

            vc1 = df[col].value_counts()
            vc2 = df.loc[~flags, col].value_counts() 

            cats = sorted(set(vc1.index) | set(vc2.index))
            v1 = [vc1.get(c, 0) for c in cats]
            v2 = [vc2.get(c, 0) for c in cats]

            ax[i,0].bar(cats, v1)
            ax[i,0].set_title(f'{col} with MV')

            ax[i,1].bar(cats, v2)
            ax[i,1].set_title(f'{col} without MV')

            diff = np.abs(np.array(v1) - np.array(v2))
            ax[i,2].bar(cats, diff)
            ax[i,2].set_title('Difference')

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# dtype: int64

# %%
from sklearn.neighbors import KNeighborsRegressor

features = ['Pclass', 'SibSp', 'Parch', 'Fare']

train = df[df['Age'].notna()]
test = df[df['Age'].isna()]

knn = KNeighborsRegressor(n_neighbors=5)

knn.fit(train[features], train['Age'])

df.loc[df['Age'].isna(), 'Age'] = knn.predict(test[features])

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 884         0       2    male  27.0      0      0  13.0000        S
# 885         1       1  female  19.0      0      0  30.0000        S
# 886         0       3  female  26.8      1      2  23.4500        S
# 887         1       1    male  26.0      0      0  30.0000        C
# 888         0       3    male  32.0      0      0   7.7500        Q
#
# [889 rows x 8 columns]

# %%
# df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
# df

# %%
df['Embarked'] = df['Embarked'].map({
    'C': 'Cherbourg',
    'Q': 'Queenstown',
    'S': 'Southampton'
})
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare     Embarked
# 0           0       3    male  22.0      1      0   7.2500  Southampton
# 1           1       1  female  38.0      1      0  71.2833    Cherbourg
# 2           1       3  female  26.0      0      0   7.9250  Southampton
# 3           1       1  female  35.0      1      0  53.1000  Southampton
# 4           0       3    male  35.0      0      0   8.0500  Southampton
# ..        ...     ...     ...   ...    ...    ...      ...          ...
# 884         0       2    male  27.0      0      0  13.0000  Southampton
# 885         1       1  female  19.0      0      0  30.0000  Southampton
# 886         0       3  female  26.8      1      2  23.4500  Southampton
# 887         1       1    male  26.0      0      0  30.0000    Cherbourg
# 888         0       3    male  32.0      0      0   7.7500   Queenstown
#
# [889 rows x 8 columns]

# %%
# df= pd.get_dummies(df, drop_first=False, dtype=np.float64) 
# df

# %%
cols=[col for col in df.columns if col != 'Survived'] + ['Survived']
df=df[cols]
df
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare     Embarked  Survived
# 0         3    male  22.0      1      0   7.2500  Southampton         0
# 1         1  female  38.0      1      0  71.2833    Cherbourg         1
# 2         3  female  26.0      0      0   7.9250  Southampton         1
# 3         1  female  35.0      1      0  53.1000  Southampton         1
# 4         3    male  35.0      0      0   8.0500  Southampton         0
# ..      ...     ...   ...    ...    ...      ...          ...       ...
# 884       2    male  27.0      0      0  13.0000  Southampton         0
# 885       1  female  19.0      0      0  30.0000  Southampton         1
# 886       3  female  26.8      1      2  23.4500  Southampton         0
# 887       1    male  26.0      0      0  30.0000    Cherbourg         1
# 888       3    male  32.0      0      0   7.7500   Queenstown         0
#
# [889 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

label_encoder = LabelEncoder()

df = df.copy()

for col in df.select_dtypes(include='category').columns:
    df[col] = label_encoder.fit_transform(df[col])
    print(label_encoder.classes_) 
df
# Out:
# ['female' 'male']
#      Pclass  Sex   Age  SibSp  Parch     Fare     Embarked  Survived
# 0         3    1  22.0      1      0   7.2500  Southampton         0
# 1         1    0  38.0      1      0  71.2833    Cherbourg         1
# 2         3    0  26.0      0      0   7.9250  Southampton         1
# 3         1    0  35.0      1      0  53.1000  Southampton         1
# 4         3    1  35.0      0      0   8.0500  Southampton         0
# ..      ...  ...   ...    ...    ...      ...          ...       ...
# 884       2    1  27.0      0      0  13.0000  Southampton         0
# 885       1    0  19.0      0      0  30.0000  Southampton         1
# 886       3    0  26.8      1      2  23.4500  Southampton         0
# 887       1    1  26.0      0      0  30.0000    Cherbourg         1
# 888       3    1  32.0      0      0   7.7500   Queenstown         0
#
# [889 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df = df.copy()

cols = ['Sex', 'Embarked']

for col in cols:
    df[col] = label_encoder.fit_transform(df[col])
    print(col, label_encoder.classes_)
    
df
# Out:
# Sex [0 1]
# Embarked ['Cherbourg' 'Queenstown' 'Southampton']
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Survived
# 0         3    1  22.0      1      0   7.2500         2         0
# 1         1    0  38.0      1      0  71.2833         0         1
# 2         3    0  26.0      0      0   7.9250         2         1
# 3         1    0  35.0      1      0  53.1000         2         1
# 4         3    1  35.0      0      0   8.0500         2         0
# ..      ...  ...   ...    ...    ...      ...       ...       ...
# 884       2    1  27.0      0      0  13.0000         2         0
# 885       1    0  19.0      0      0  30.0000         2         1
# 886       3    0  26.8      1      2  23.4500         2         0
# 887       1    1  26.0      0      0  30.0000         0         1
# 888       3    1  32.0      0      0   7.7500         1         0
#
# [889 rows x 8 columns]

# %%
# list_ = ["sex","smoker"]
# for col in list_:
#     df[col] = label_encoder.fit_transform(df[col])
#     print(label_encoder.classes_)
# df

# %%
df['Sex'] = df['Sex'].astype('float')
df['Embarked'] = df['Embarked'].astype('float')
df['Pclass'] = df['Pclass'].astype('float')
df['SibSp'] = df['SibSp'].astype('float')
df['Parch'] = df['Parch'].astype('float')
df['Survived'] = df['Survived'].astype('float')
df
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Survived
# 0       3.0  1.0  22.0    1.0    0.0   7.2500       2.0       0.0
# 1       1.0  0.0  38.0    1.0    0.0  71.2833       0.0       1.0
# 2       3.0  0.0  26.0    0.0    0.0   7.9250       2.0       1.0
# 3       1.0  0.0  35.0    1.0    0.0  53.1000       2.0       1.0
# 4       3.0  1.0  35.0    0.0    0.0   8.0500       2.0       0.0
# ..      ...  ...   ...    ...    ...      ...       ...       ...
# 884     2.0  1.0  27.0    0.0    0.0  13.0000       2.0       0.0
# 885     1.0  0.0  19.0    0.0    0.0  30.0000       2.0       1.0
# 886     3.0  0.0  26.8    1.0    2.0  23.4500       2.0       0.0
# 887     1.0  1.0  26.0    0.0    0.0  30.0000       0.0       1.0
# 888     3.0  1.0  32.0    0.0    0.0   7.7500       1.0       0.0
#
# [889 rows x 8 columns]

# %%
print(df.mean())
print()
print('*' * 50) 
print(df.median())
print()
print('*' * 50) 
print(df.mode())
print('*' * 50)
# Out:
# Pclass       2.311586
# Sex          0.649044
# Age         30.089132
# SibSp        0.524184
# Parch        0.382452
# Fare        32.096681
# Embarked     1.535433
# Survived     0.382452
# dtype: float64
#
# **************************************************
# Pclass       3.0000
# Sex          1.0000
# Age         29.0000
# SibSp        0.0000
# Parch        0.0000
# Fare        14.4542
# Embarked     2.0000
# Survived     0.0000
# dtype: float64
#
# **************************************************
#    Pclass  Sex   Age  SibSp  Parch  Fare  Embarked  Survived
# 0     3.0  1.0  24.0    0.0    0.0  8.05       2.0       0.0
# **************************************************

# %%
# df.mean(numeric_only=True)

# %%
df.std()  #انحراف معیار
df.var()  #واریانس
# Out:
# Pclass         0.696724
# Sex            0.228042
# Age          182.144819
# SibSp          1.218164
# Parch          0.650863
# Fare        2469.841935
# Embarked       0.627403
# Survived       0.236448
# dtype: float64

# %%
print(list(enumerate(df.columns)))

fig, axes = plt.subplots(2, 4, figsize=(17, 10))

axes_flat = axes.flatten()

for i, col in enumerate(df.columns):
    ax = axes_flat[i]
    
    ax.hist(df[col])
    ax.set_title(col)
    ax.grid(False)

plt.tight_layout()
plt.show()
# Out:
# [(0, 'Pclass'), (1, 'Sex'), (2, 'Age'), (3, 'SibSp'), (4, 'Parch'), (5, 'Fare'), (6, 'Embarked'), (7, 'Survived')]

# %%
plt.boxplot(df.Age);
df.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  889.000000  889.000000  889.000000  889.000000  889.000000  889.000000
# mean     2.311586    0.649044   30.089132    0.524184    0.382452   32.096681
# std      0.834700    0.477538   13.496104    1.103705    0.806761   49.697504
# min      1.000000    0.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000   21.584000    0.000000    0.000000    7.895800
# 50%      3.000000    1.000000   29.000000    0.000000    0.000000   14.454200
# 75%      3.000000    1.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000    1.000000   80.000000    8.000000    6.000000  512.329200
#
#          Embarked    Survived
# count  889.000000  889.000000
# mean     1.535433    0.382452
# std      0.792088    0.486260
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      2.000000    0.000000
# 75%      2.000000    1.000000
# ...

# %%
plt.boxplot(df.Fare);

# %%
plt.figure(figsize=(14, 14))
sns.heatmap(df.corr(), annot=True);# ,mask=mask

# %%
sns.countplot(data=df, x='Sex', hue='Survived')

plt.show()

# %%
pd.crosstab(df['Sex'], df['Survived'])
# Out:
# Survived  0.0  1.0
# Sex
# 0.0        81  231
# 1.0       468  109

# %%
sns.countplot(data=df, x='Pclass', hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
pd.crosstab(df['Pclass'], df['Survived'])
# Out:
# Survived  0.0  1.0
# Pclass
# 1.0        80  134
# 2.0        97   87
# 3.0       372  119

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df, x='Survived', y='Age')

plt.xlabel('Survived')
plt.ylabel('Age')
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#             Pclass       Sex       Age     SibSp     Parch      Fare  \
# Pclass    1.000000  0.127741 -0.356594  0.081656  0.016824 -0.548193
# Sex       0.127741  1.000000  0.099027 -0.116348 -0.247508 -0.179958
# Age      -0.356594  0.099027  1.000000 -0.223682 -0.191424  0.086115
# SibSp     0.081656 -0.116348 -0.223682  1.000000  0.414542  0.160887
# Parch     0.016824 -0.247508 -0.191424  0.414542  1.000000  0.217532
# Fare     -0.548193 -0.179958  0.086115  0.160887  0.217532  1.000000
# Embarked  0.164681  0.110320 -0.026576  0.068900  0.040449 -0.226311
# Survived -0.335549 -0.541585 -0.065525 -0.034040  0.083151  0.255290
#
#           Embarked  Survived
# Pclass    0.164681 -0.335549
# Sex       0.110320 -0.541585
# Age      -0.026576 -0.065525
# SibSp     0.068900 -0.034040
# Parch     0.040449  0.083151
# Fare     -0.226311  0.255290
# Embarked  1.000000 -0.169718
# Survived -0.169718  1.000000

# %%
sns.countplot(data=df, x='Pclass', hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.boxplot(data=df, x='Survived', y='Fare')

plt.xlabel('Survived')
plt.ylabel('Fare')
plt.show()

# %%
plt.scatter(df.Fare, df.Age);
plt.xlabel('Fare')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
flags = df.Survived == 1
plt.scatter(df.Age[flags], df.Fare[flags], c='r', label='Survived_yes',alpha=0.3)
plt.scatter(df.Age[~flags], df.Fare[~flags], c='b', label='Survived_no',alpha=0.2)  
plt.legend();

# %%
df.groupby('Sex')['Fare'].mean()
# Out:
# Sex
# 0.0    44.252124
# 1.0    25.523893
# Name: Fare, dtype: float64

# %%
sns.barplot(data=df, x='Sex', y='Fare')

plt.xlabel('Sex')
plt.ylabel(' Fare')
plt.show()

# %%
sns.boxplot(data=df, x='Pclass', y='Fare', hue='Sex')

plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.show()

# %%
sns.catplot(
    data=df,
    x='Pclass',
    y='Fare',
    hue='Sex',
    col='Survived',
    kind='box'
)
plt.show()

# %%
df.groupby('Survived')['Fare'].mean()
# Out:
# Survived
# 0.0    22.117887
# 1.0    48.209498
# Name: Fare, dtype: float64

# %%
sns.countplot(data=df, x='Embarked', hue='Pclass')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(
    data=df,
    x='Embarked',
    hue='Survived'
)

plt.show()

# %%
sns.countplot(
    data=df[df['Pclass'] == 2],
    x='Sex',
    hue='Survived'
)

plt.show()

# %%
pd.crosstab(df['Sex'], df['Embarked'])
# Out:
# Embarked  0.0  1.0  2.0
# Sex
# 0.0        73   36  203
# 1.0        95   41  441

# %%
import numpy as np

num_cols = df.select_dtypes(include=np.number).columns

for col in num_cols:
    mean = df[col].mean()
    std = df[col].std()
    
    lower = mean - 3 * std
    upper = mean + 3 * std
    
    outliers = df[(df[col] < lower) | (df[col] > upper)]
    
    print(f'Column: {col}')
    print(f'Mean: {mean:.2f}')
    print(f'Std: {std:.2f}')
    print(f'Lower: {lower:.2f}')
    print(f'Upper: {upper:.2f}')
    print(f'Number of outliers: {len(outliers)}')
    print('--------------------')
# Out:
# Column: Pclass
# Mean: 2.31
# Std: 0.83
# Lower: -0.19
# Upper: 4.82
# Number of outliers: 0
# --------------------
# Column: Sex
# Mean: 0.65
# Std: 0.48
# Lower: -0.78
# Upper: 2.08
# Number of outliers: 0
# --------------------
# Column: Age
# Mean: 30.09
# Std: 13.50
# Lower: -10.40
# Upper: 70.58
# Number of outliers: 4
# --------------------
# Column: SibSp
# Mean: 0.52
# Std: 1.10
# Lower: -2.79
# Upper: 3.84
# Number of outliers: 30
# --------------------
# Column: Parch
# Mean: 0.38
# Std: 0.81
# Lower: -2.04
# Upper: 2.80
# Number of outliers: 15
# --------------------
# Column: Fare
# Mean: 32.10
# Std: 49.70
# Lower: -117.00
# Upper: 181.19
# Number of outliers: 20
# --------------------
# Column: Embarked
# Mean: 1.54
# Std: 0.79
# Lower: -0.84
# Upper: 3.91
# Number of outliers: 0
# --------------------
# Column: Survived
# Mean: 0.38
# Std: 0.49
# Lower: -1.08
# Upper: 1.84
# Number of outliers: 0
# --------------------

# %%
for col in ['Age', 'Fare']:
    mean = df[col].mean()
    std = df[col].std()

    lower = mean - 3 * std
    upper = mean + 3 * std

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(col)
    print("Mean:", mean)
    print("Std:", std)
    print("Lower:", lower)
    print("Upper:", upper)
    print("Number of Outliers:", len(outliers))
    print("Outliers:")
    print(outliers[col].values)
    print("----------------------")
# Out:
# Age
# Mean: 30.089131608548932
# Std: 13.496103842247315
# Lower: -10.399179918193013
# Upper: 70.57744313529088
# Number of Outliers: 4
# Outliers:
# [71. 71. 80. 74.]
# ----------------------
# Fare
# Mean: 32.09668087739032
# Std: 49.697504316707956
# Lower: -116.99583207273355
# Upper: 181.1891938275142
# Number of Outliers: 20
# Outliers:
# [263.     263.     247.5208 512.3292 247.5208 262.375  263.     211.5
#  227.525  263.     221.7792 227.525  512.3292 211.3375 227.525  227.525
#  211.3375 512.3292 262.375  211.3375]
# ----------------------

# %%
df_original = pd.read_csv(r'C:\Users\HAMTA\Desktop\AI\titanic (1).csv')

df_original[df_original['Age'] == 80][
    ['Name', 'Age', 'Sex', 'Pclass', 'Survived', 'Fare', 'Embarked']]
# Out:
#                                      Name   Age   Sex  Pclass  Survived  Fare  \
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0  male       1         1  30.0
#
#     Embarked
# 630        S

# %%
df_original = pd.read_csv(r'C:\Users\HAMTA\Desktop\AI\titanic (1).csv')

df_original[df_original['Age'] == 71][
    ['Name', 'Age', 'Sex', 'Pclass', 'Survived', 'Fare', 'Embarked']]
# Out:
#                           Name   Age   Sex  Pclass  Survived     Fare Embarked
# 96   Goldschmidt, Mr. George B  71.0  male       1         0  34.6542        C
# 493    Artagaveytia, Mr. Ramon  71.0  male       1         0  49.5042        C

# %%
df_original = pd.read_csv(r'C:\Users\HAMTA\Desktop\AI\titanic (1).csv')

df_original[df_original['Age'] == 74][
    ['Name', 'Age', 'Sex', 'Pclass', 'Survived', 'Fare', 'Embarked']]
# Out:
#                     Name   Age   Sex  Pclass  Survived   Fare Embarked
# 851  Svensson, Mr. Johan  74.0  male       3         0  7.775        S

# %%
# def normalization(x):
#     return (x - x.min()) / (x.max() - x.min())

# %%
# def wisker(col):
#     Q1 , Q3 = np.percentile(col,[25,75])
#     IQR = Q3 - Q1
#     upper_bound = Q3 + 1.5 * IQR
#     lower_bound = Q1 -  1.5 * IQR   

#     return lower_bound , upper_bound

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()   #بین صفر و یک
# df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()   #zscor

# df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])

# %%
df_original = df.copy()

# %%
# قبل از Scaling
plt.plot(df_original['Age'], label='Age')
plt.plot(df_original['Fare'], label='Fare')
plt.legend()
plt.title('Before Scaling')
plt.show()

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

columns_to_scale = ['Age', 'Fare']

df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# %%
# بعد از Scaling
plt.plot(df['Age'], label='Age')
plt.plot(df['Fare'], label='Fare')
plt.legend()
plt.title('After RobustScaler')
plt.show()
